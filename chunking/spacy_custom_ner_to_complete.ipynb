# %% [markdown]
# <a href="https://colab.research.google.com/github/Ddungi813/780demo/blob/main/chunking/spacy_custom_ner_to_complete.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # spaCy for named entity recognition of clinical concepts
#
# In this practical, we will build a named entity recognition (NER) classifier using spaCy.
#
# Named entity recognition is a structured learning problem, i.e., we want to learn sequence patterns.
#
# We will use data from mtsamples again, and build classifiers that find clinical concepts.
#
# The 'gold' standard data is *not* manually annotated, it is the output of a clinical concept recognition system developed by Zeljko Kraljevic called 'CAT' (a predecessor to MedCAT), thus this data is not perfect, but it will do to illustrate the idea. MedCAT matches concepts to the entire UMLS. We will only use a few example concepts here.
#
# Part of this material is adapted, inspired etc from:
#
# https://spacy.io/usage/training
#
#
# Written by Angus Roberts, May 2023, for spaCy 3. Based on an earlier version for spaCy 2 written by Sumithra Velupillai, March 2019. Acknowledgements and many thanks to Zeljko Kraljevic for the data preparation.

# %%
# We'll use spaCy for NER.
try:
    import spacy
except ImportError as e:
    # !pip install spacy
    import spacy

# DocBin is a serialisable collection of spacy
# Documents.
from spacy.tokens import DocBin

# Displacy provides a graphic display of
# documents and annotations, and Scorer scores...
from spacy import displacy
from spacy.scorer import Scorer

# Example holds spacy documents,
# one with predicted annotations
# and one with gold standard .
# We will use it when evalusating.
from spacy.training import Example


# requests is a package to submit requests to URLs
# We will use it to fetch our data
import requests

# we use sklearn to split our training data in to train
# and dev portions (we have a separate, held out
# final test set)
from sklearn.model_selection import train_test_split

# We will generate warnings for some thing
# You might uncomment to ignore them
import warnings
#warnings.filterwarnings('ignore')

# %% [markdown]
# # 1: What version of spaCy do we have?
# SpaCy has changed a lot between V2 and V3, let's check we have the right version - we want V3

# %%
# !python -m spacy info
# Out:
# ============================== Info about spaCy ==============================
#
# spaCy version    3.8.14
# Location         /usr/local/lib/python3.12/dist-packages/spacy
# Platform         Linux-6.6.113+-x86_64-with-glibc2.35
# Python version   3.12.13
# Pipelines        en_core_web_sm (3.8.0)

# %% [markdown]
# # 2: Reading in the corpus
# Our data is in a json format which derives from an older version of spaCy. We will start by reading it in to a Python compund data structure.

# %%
data_url = 'https://github.com/KCL-Health-NLP/nlp_examples/blob/master/chunking/chunking_traindata_CAT_updated_2021.json?raw=true'
r = requests.get(data_url)
data = r.json()

# %% [markdown]
# How big is our dataset?

# %%
# Write this code yourself
len(data)
# Out:
# 153

# %% [markdown]
# Let's take a look at a random document and its annotations.

# %%
# Write this code yourself
data[150]
# Out:
# ["\r\n        \r\n        \r\n\r\n        \r\n        \nPRESENTATION: \n A 16-year-old male presents to the emergency department (ED) with rectal bleeding and pain on defecation.\n\n\nHISTORY:\n  A 16-year-old African American male presents to the ED with a chief complaint of rectal bleeding and pain on defecation.  The patient states that he was well until about three days prior to presentation when he first started to experience some pain when defecating.  The following day he noted increasing pain and first noted blood on the surface of his stool.  The pain worsened on the subsequent day with increasing bleeding as well as some mucopurulent anal discharge.  The patient denies any previous history of rectal bleeding or pain.  He also denies any previous sexually transmitted diseases (STDs) and states that he was screened for HIV infection eight months ago and was negative.  The patient does state that he has not felt well for the past week.  He states that he had felt &amp;quot;feverish&amp;quot; on several occasions but has not taken his temperature.  He has also complained of some abdominal discomfort with nausea and diarrhea as well as generalized myalgias and fatigue.  He thinks he has lost a few pounds but has not been weighing himself to determine the exact amount of weight loss.\n\nThe patient states that he has been sexually active since age 13.  He admits to eight previous partners and states that he &amp;quot;usually&amp;quot; uses a condom.  On further questioning, the patient states that of his eight partners, three were female and five were male.  His most recent sexual partner was a 38-year-old man whom he has been with for the past six months.  He states that he has been tested for STDs in the past but states that he only gave urine and blood for the testing.  He is unaware of the HIV status of his partner but assumes that the partner is uninfected because he looks healthy.  The patient also admits to one episode of sexual abuse at the age of 8 by a friend of the family.  As the man was a member of the family's church, the patient never felt comfortable disclosing this to any of the adults in his life.  He is very concerned about disclosure of his sexual behavior to his family, as they have expressed very negative comments concerning men who have sex with men.  He is accessing care in the ED unaccompanied by an adult.\n\n\nPHYSICAL EXAM: \n Thin but non-toxic young man with clear discomfort.\nPulse = 105\nRR = 23\nBP = 120/62\nHEENT:  Several areas of white plaque-like material on the buccal mucosa.\nNeck:  Multiple anterior/posterior cervical nodes in both anterior and posterior chains- 1-2 cm in diameter.\nLungs:  Clear to auscultation.\nCardiac:  Quiet precordium.\nNl S1/S2 with a II/VI systolic murmur. \nAbdomen:  Soft without hepatosplenomegaly.\nGU:  Tanner V male with no external penile lesions.\nLymph:  2-3 cm axillary nodes bilaterally.\n1-2 cm epitrochlear nodes.\nMultiple 1-2 cm inguinal nodes.\nRectal:  Extremely painful digital exam.\n+ gross blood and mucous.\n\n\nLABORATORY EVALUATION:\n\nHbg = 12.  5 gm/dL\nHct = 32%\nWBC = 3.9 thou/&amp;micro;L\nPlatelets = 120,000 thou/&amp;micro;L\n76% neutrophils\n19% lymphocytes\n1% eosinophils\n4% monocytes\nALT = 82 U/L\nAST= 90 U/L\nErythrocyte sedimentation rate = 90\nElectrolytes = normal\nGram stain of anal swab:  numerous WBCs\n\n\nDIFFERENTIAL DIAGNOSIS: \n This patient is presenting with acute rectal pain with bleeding and anal discharge.  The patient also presents with some constitutional symptoms including fever, fatigue, abdominal discomfort, and adenopathy on physical examination.  The following are in the differential diagnosis:  Acute Proctitis and  Proctocolitis.\n\n\nACUTE HIV SEROCONVERSION: \n This subject is sexually active and reports inconsistent condom use.  Gastrointestinal symptoms have recently been reported commonly in patients with a history of HIV seroconversion.  The rectal symptoms of bleeding and pain are not common with HIV ...
#  {'entities': [[634, 638, 'ANATOMY'],
#    [2519, 2532, 'ANATOMY'],
#    [2643, 2648, 'ANATOMY'],
#    [2674, 2681, 'ANATOMY'],
#    [2821, 2827, 'ANATOMY'],
#    [2852, 2866, 'ANATOMY'],
#    [3284, 3288, 'ANATOMY'],
#    [3406, 3410, 'ANATOMY'],
#    [4048, 4052, 'ANATOMY'],
#    [5511, 5515, 'ANATOMY'],
#    [5520, 5530, 'ANATOMY'],
#    [5595, 5599, 'ANATOMY'],
#    [5737, 5741, 'ANATOMY'],
#    [748, 777, 'DISEASESYNDROME'],
#    [821, 834, 'DISEASESYNDROME'],
#    [1708, 1712, 'DISEASESYNDROME'],
#    [3535, 3545, 'DISEASESYNDROME'],
#    [3622, 3637, 'DISEASESYNDROME'],
#    [3643, 3656, 'DISEASESYNDROME'],
#    [3999, 4006, 'DISEASESYNDROME'],
#    [4104, 4111, 'DISEASESYNDROME'],
#    [4797, 4810, 'DISEASESYNDROME'],
#    [5385, 5389, 'DISEASESYNDROME'],
#    [5657, 5661, 'DISEASESYNDROME'],
#    [5873, 5888, 'DISEASESYNDROME'],
#    [6057, 6066, 'DISEASESYNDROME'],
#    [6687, 6700, 'DISEASESYNDROME'],
#    [145, 149, 'SIGNSYMPTOM'],
#    [279, 283, 'SIGNSYMPTOM'],
#    [422, 426, 'SIGNSYMPTOM'],
#    [483, 487, 'SIGNSYMPTOM'],
#    [544, 548, 'SIGNSYMPTOM'],
#    [713, 717, 'SIGNSYMPTOM'],
#    [977, 985, 'SIGNSYMPTOM'],
#    [1084, 1104, 'SIGNSYMPTOM'],
#    [1110, 1116, 'SIGNSYMPTOM'],
#    [1121, 1129, 'SIGNSYMPTOM'],
#    [1153, 1161, 'SIGNSYMPTOM'],
#    [1166, 1173, 'SIGNSYMPTOM'],
#    [2416, 2426, 'SIGNSYMPTOM'],
#    [2765, 2783, 'SIGNSYMPTOM'],
#    [2958, 2965, 'SIGNSYMPTOM'],
#    [3376, 3387, 'SIGNSYMPTOM'],
#    [3459, 3482, 'SIGNSYMPTOM'],
#    [3493, 3498, 'SIGNSYMPTOM'],
#    [3500, 3507, 'SIGNSYMPTOM'],
#    [3509, 3529, 'SIGNSYMPTOM'],
#    [3758, 3783, 'SIGNSYMPTOM'],
#    [3876, 3891, 'SIGNSYMPTOM'],
#    [3908, 3912, 'SIGNSYMPTOM'],
#    [4196, 4204, 'SIGNSYMPTOM'],
#    [4210, 4215, 'SIGNSYMPTOM'],
#    [4220, 4227, 'SIGNSYMPTOM'],
#    [4337, 4341, 'SIGNSYMPTOM'],
#    [4346, 4351, 'SIGNSYMPTOM'],
#    [5719, 5727, 'SIGNSYMPTOM']]}]

# %% [markdown]
# The json format is a list of documents, each document being a list that contains:
# * [the text itself,
# * {a dictionary with
#   * a key string 'entities'
#   * [a value that is a list containing all the annotated entities
#     * [each annotated entity is itself a list with
#       * the start character offset for the entity
#       * the end character offsets for the entity
#       * the type of the entity]]}]
#
# What are the instances we want to learn?

# %% [markdown]
# We will split our data 80:20 in to a train set for training and a dev set for testing at each training iteration. We will do this with scikit learn's train_test_split function. Note that we also have a separate, held out test set that we will keep blind, and read in later on in the notebook.
#
# Take a look at the documentation for [train_test_split](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) and work out how to do this. Write the code below, calling the two datasets train_data and dev_data.

# %%
# Complete this code yourself
train_data, dev_data = train_test_split(data, test_size=0.2, random_state=42)

# %% [markdown]
# # 3: Converting the corpus to .spacy format
# When training spaCy, we need to pass it a binary file of serialised spaCy *Document* objects. SpaCy *DocBin* objects help with this. They are iterable collections of Documents which can be serialised.
#
# We will write a function that takes our json corpus and converts it to a DocBin.

# %%
  # SpaCy documents record the token spans of annotations.
  # We therefore need to get the token spans of our
  # annotations, so we can save these in the Documents.
  # We can do this with a blank spaCy pipeline with no
  # components. No need to do any other processing.
  nlp = spacy.blank('en')

# %%
# A DocBin is a serialisable SpaCy container that holds
# SpaCy documents, and which can be used in SpaCy training.
# This function converts our data format in to a DocBin
def data_to_docbin(json_corpus):

  # We create a DocBin to hold out Documents
  db = DocBin()

  # The json_corpus contains text and annotations
  for text, annot in json_corpus:

    # create Document object from text
    # this will conatin the tokens and
    # their spans
    doc = nlp(text)

    # Now let's get the entities in to a list
    ents = []

    # The annotations from our data have a start offset,
    # an end offset and a label
    for start, end, label in annot["entities"]:

      # Make a span in our document for these
      span = doc.char_span(start, end, label=label)

      # If the Document can't align the character offsets with tokens,
      # it will return None. We will ignore any entities like this,
      # as they could break our training
      if span is None:
        warnings.warn(f'Skipping entity [{start}, {end}, {label}] : span does not align with token boundaries')
      else:
        ents.append(span)

    # Add the entities to the document
    # and add the document to the DocBin
    doc.set_ents(ents)
    db.add(doc)

  # return the DocBin containing all the Documents
  # with their text and entities
  return db

# %% [markdown]
# Now let's use this function to create DocBins for our train data and our dev data, and write these to disk. Complete the code below to do this.

# %%
# Now convert our two datasets and serialise them
# to disk ready for training - you need to
# complete the code to do this

# Complete the code below
train_doc_bin = data_to_docbin(train_data)
train_doc_bin.to_disk("./train.spacy")

# Complete the code below
dev_doc_bin = data_to_docbin(dev_data)
dev_doc_bin.to_disk("./dev.spacy")
# Out:
# /tmp/ipykernel_3991/3686686224.py:31: UserWarning: Skipping entity [314, 323, SIGNSYMPTOM] : span does not align with token boundaries
#   warnings.warn(f'Skipping entity [{start}, {end}, {label}] : span does not align with token boundaries')
# /tmp/ipykernel_3991/3686686224.py:31: UserWarning: Skipping entity [972, 982, SIGNSYMPTOM] : span does not align with token boundaries
#   warnings.warn(f'Skipping entity [{start}, {end}, {label}] : span does not align with token boundaries')
# /tmp/ipykernel_3991/3686686224.py:31: UserWarning: Skipping entity [1711, 1725, DISEASESYNDROME] : span does not align with token boundaries
#   warnings.warn(f'Skipping entity [{start}, {end}, {label}] : span does not align with token boundaries')
# /tmp/ipykernel_3991/3686686224.py:31: UserWarning: Skipping entity [92, 94, DISEASESYNDROME] : span does not align with token boundaries
#   warnings.warn(f'Skipping entity [{start}, {end}, {label}] : span does not align with token boundaries')
# /tmp/ipykernel_3991/3686686224.py:31: UserWarning: Skipping entity [977, 985, SIGNSYMPTOM] : span does not align with token boundaries
#   warnings.warn(f'Skipping entity [{start}, {end}, {label}] : span does not align with token boundaries')
# /tmp/ipykernel_3991/3686686224.py:31: UserWarning: Skipping entity [221, 223, DISEASESYNDROME] : span does not align with token boundaries
#   warnings.warn(f'Skipping entity [{start}, {end}, {label}] : span does not align with token boundaries')
# /tmp/ipykernel_3991/3686686224.py:31: UserWarning: Skipping entity [73, 75, DISEASESYNDROME] : span does not align with token boundaries
#   warnings.warn(f'Skipping entity [{start}, {end}, {label}] : span does not align with token boundaries')
# /tmp/ipykernel_3991/3686686224.py:31: UserWarning: Skipping entity [1002, 1008, ANATOMY] : span does not align with token boundaries
#   warnings.warn(f'Skipping entity [{start}, {end}, {label}] : span does not align with token boundaries')
# /tmp/ipykernel_3991/3686686224.py:31: UserWarning: Skipping entity [1010, 1026, DISEASESYNDROME] : span does not align with token boundaries
#   warnings.warn(f'Skipping entity [{start}, {end}, {label}] : span does not align with token boundaries')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# We can read one of them in to check it's worked

# %%
# Let's check we can deserialise
doc_bin = DocBin().from_disk("./train.spacy")
docs = list(doc_bin.get_docs(nlp.vocab))
print(len(docs))
# Out:
# 122

# %% [markdown]
# # 4: Training a named entity model with spaCy
# The default named entity pipe in spaCy is trained to recognise traditional named entities, such as people and places. We have our own medical named entities that we want to develop a model for.
#
# You can train spaCy models in Python code, passing samples of your data to the pipeline in a training loop. However spaCy V3 is designed around running many common operations, including training, from a command line interface (CLI). You run spaCy commands from a command line, passing in any data and a configuration file. The configuration file lets you set parameters, data paths, scoring methods, and many more things. It's a flexible approach, and means that you will always be using the most efficient code, and can concentrate on configuring your pipeline.
#
# The first thing we need to do is create a config file. There are lots of options, so the best way is to generate a template using spaCy's online tool, which is here:
#
# https://spacy.io/usage/training#quickstart
#
# You can play with different settings, but to start we recommend:
#
# * Language: English
# * Components: parser and ner (you need both!)
# * Hardware: CPU
# * Optimise for: efficiency
#
# Do the following:
# 1.   Go to https://spacy.io/usage/training#quickstart
# 2.   Choosen the above settings
# 3.   Click the download icon on the config file display (bottom right)
# 4.   Save the config file to your local computer
# 5.   Upload the config to colab.
#
# Once you have done this, you will have a base_config.cfg file in your colab file space. This is not a complete config, and needs some parameters filling in and initialising for your system. Do this by running the following command to the spacy CLI:

# %%
#참고 : 파일 생성법
config_text = """여기에 너 config 전체 붙여넣기"""

with open("base_config.cfg", "w") as f:
    f.write(config_text)

# %%
# !cp /content/drive/MyDrive/base_config.cfg .
# Out:
# cp: cannot stat '/content/drive/MyDrive/base_config.cfg': No such file or directory

# %%
# Initialise spacy config file
#!python -m spacy init fill-config base_config.cfg config.cfg
# !python -m spacy init fill-config /content/base_config.cfg /content/config.cfg
# Out:
# ✔ Auto-filled config with all values
# ✔ Saved config
# /content/config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %% [markdown]
# You now have a config.cfg file. SpaCy will use this for all settings during training. However, it will still need a couple of settings, which you can supply at the command line (overriding values in the config.cfg file):
#
# * output directory for the trained model
# * path to the train dataset
# * path to the dev dataset
#
# The following command runs spacy's training using config.cfg. You need to complete it to pass in the paths to our prepared train and dev set to it. Edit it to include these paths, and then run it:

# %%
# You need to fill in the training and dev dataset paths before running!
#!python -m spacy train config.cfg --output ./output --paths.train PUT-PATH_HERE --paths.dev PUT-PATH_HERE
# !python -m spacy train /content/config.cfg \
--output /content/drive/MyDrive/nlp_output \
--paths.train /content/train.spacy \
--paths.dev /content/dev.spacy
# Out:
# ✔ Created output directory: /content/drive/MyDrive/nlp_output
# ℹ Saving to output directory: /content/drive/MyDrive/nlp_output
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner', 'parser']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  LOSS PARSER  ENTS_F  ENTS_P  ENTS_R  DEP_UAS  DEP_LAS  SENTS_F  SCORE
# ---  ------  ------------  --------  -----------  ------  ------  ------  -------  -------  -------  ------
#   0       0          0.00    195.14         0.00    0.07    0.05    0.14     0.00     0.00     0.00    0.00
#   1     200      14912.81  15398.09         0.00    5.09   82.61    2.62     0.00     0.00     0.00    0.03
#   3     400       1834.04   8073.30         0.00   13.20   81.25    7.18     0.00     0.00     0.00    0.07
#   4     600       2505.60   7735.60         0.00   22.45   65.77   13.54     0.00     0.00     0.00    0.11
#   6     800       2481.59   7325.68         0.00   23.88   62.21   14.78     0.00     0.00     0.00    0.12
#   8    1000       2618.76   7884.00         0.00   15.04   81.08    8.29     0.00     0.00     0.00    0.08
#   9    1200       2914.91   7596.83         0.00   19.54   84.21   11.05     0.00     0.00     0.00    0.10
#  11    1400       2955.07   7077.53         0.00   21.43   77.59   12.43     0.00     0.00     0.00    0.11
#  13    1600       3245.53   7550.32         0.00   18.25   85.06   10.22     0.00     0.00     0.00    0.09
#  14    1800       3428.43   7237.48         0.00   28.73   74.14   17.82     0.00     0.00     0.00    0.14
#  16    2000       3316.37   7138.79         0.00   23.34   75.19   13.81     0.00     0.00     0.00    0.12
#  18    2200       3458.06   7123.17         0.00   28.29   68.62   17.82     0.00     0.00     0.00    0.14
#  19    2400       3630.80   6875.89         0.00   27.73   75.46   16.99     0.00     0.00     0.00    0.14
#  21    2600       4015.51   7505.77         0.00   32.26   72.82   20.72     0.00     0.00     0.00    0.16
#  22    2800       3790.45   6889.48         0.00   33.86   70.93   22.24     0.00     0.00     0.00    0.17
#  24    3000       4217.74   7073.10         0.00   31.26   79.21   19.48     0.00     0.00     0.00    0.16
#  26    3200       4101.87   7018.11         0.00   34.52   71.12   22.79     0.00     0.00     0.00    0.17
#  27    3400       4005.14   6733.77         0.00   28.99   80.50   17.68     0.00     0.00     0.00    0.14
#  29    3600       4072.91   6861.15         0.00   33.97   75.00   21.96     0.00     0.00     0.00    0.17
#  31    3800       4610.84   7270.49         0.00   33.01   79.06   20.86     0.00     0.00     0.00    0.17
#  32    4000       4223.95   6736.85         0.00   27.39   82.07   16.44     0.00     0.00     0.00    0.14
#  34    4200       4239.98   6749.42         0.00   34.72   75.81   22.51     0.00     0.00     0.00    0.17
#  36    4400       4337.03   6683.27         0.00   35.56   76.02   23.20     0.00     0.00     0.00    0.18
#  37    4600       4555.37   6908.27         0.00   36.20   69.69   24.45     0.00     0.00     0.00    0.18
#  39    4800       4704.79   6714.95         0.00   35.34   75.57   23.07     0.00     0.00     0.00    0.18
#  40    5000       4610.03   6816.02         0.00   36.02   74.46   23.76     0.00     0.00     0.00    0.18
#  42    5200       4535.61   6594.98         0.00   34.66   78.54   22.24     0.00     0.00     0.00    0.17
#  44    5400       4517.52   6855.36         0.00   39.22   76.40   26.38     0.00     0.00     0.00    0.20
#  45    5600       5015.85   6713.09         0.00   39.11   73.38   26.66     0.00     0.00     0.00    0.20
#  47    5800       4950.17   7019.04         0.00   38.40   74.80   25.83     0.00     0.00     0.00    0.19
#  49    6000       5105.53   6548.77         0.00   38.04   78.11   25.14     0.00     0.00     0.00    0.19
#  50    6200       4702.71   6543.47         0.00   38.97   75.70   26.24     0.00     0.00     0.00    0.19
#  52    6400       4795.34   6774.43         0.00   38.10   71.48   25.97     0.00     0.00     0.00    0.19
#  54    6600       4992.80   6591.90         0.00   40.40   73.19   27.90     0.00     0.00     0.00    0.20
#  55    6800       4904.46   6740.53         0.00   36.13   81.55   23.20     0.00     0.00     0.00    0.18
#  57    7000       5258.29   6630.15         0.00   35.99   81.86   23.07     0.00     0.00     0.00    0.18
#  59    7200       5217.06   6521.98         0.00   39.45   82.10   25.97     0.00     0.00     0.00    0.20
#  60    7400       5107.55   6684.05         0.00   37.26   78.32   24.45     0.00     0.00     0.00    0.19
#  62    7600       5003.73   6587.96         0.00   37.19   80.65   24.17     0.00     0.00     0.00    0.19
#  64    7800       5244.36   6622.19         0.00   45.48   73.09   33.01     0.00     0.00     0.00    0.23
#  65    8000       5318.24   6780.91         0.00   37.81   85.02   24.31     0.00     0.00     0.00    0.19
#  67    8200       4919.21   6441.02         0.00   40.37   81.86   26.80     0.00     0.00     0.00    0.20
#  68    8400       6187.21   6752.77         0.00   45.69   70.93   33.70     0.00     0.00     0.00    0.23
#  70    8600       5390.51   6242.58         0.00   38.49   74.31   25.97     0.00     0.00     0.00    0.19
#  72    8800       6115.22   7221.92         0.00   39.28   84.86   25.55     0.00     0.00     0.00    0.20
#  74    9000       5382.31   6659.85         0.00   45.40   77.85   32.04     0.00     0.00     0.00    0.23
#  75    9200       5470.27   6697.86         0.00   41.46   77.36   28.31     0.00     0.00     0.00    0.21
#  77    9400       6039.19   7349.60         0.00   39.58   80.51   26.24     0.00     0.00     0.00    0.20
#  79    9600       5788.20   7142.75         0.00   41.04   83.47   27.21     0.00     0.00     0.00    0.21
#  81    9800       6764.90   7070.14         0.00   38.78   81.78   25.41     0.00     0.00     0.00    0.19
#  83   10000       6605.15   7949.07         0.00   43.00   77.90   29.70     0.00     0.00     0.00    0.21
# ✔ Saved pipeline to output directory
# /content/drive/MyDrive/nlp_output/model-last

# %% [markdown]
# What do the different parts of the training report mean?

# %% [markdown]
# We have now trained a clinical concept entity recognizer, and saved it to the model directory in our workspace.

# %% [markdown]
# # 5: Take a look at some examples
#
#  Let's look at an example document and the predicted entities from the new model. We will do this with the displacy package.
#
# * Try a few documents
# * Are they right?
# * Any problems?

# %%
# Get a document
text = train_data[17][0]

# Load the model that was saved to disk by spacy train
ner = spacy.load('/content/drive/MyDrive/nlp_output/model-last')

# Process the document
doc = ner(text)

# Set up some colours for displacy
colors = {'ANATOMY': 'lightyellow',
           'DISEASESYNDROME': 'pink',
           'SIGNSYMPTOM': 'lightgreen'}

# Display in displacy
displacy.render(doc, style='ent', jupyter=True, options={'colors':colors})
# Out:
# <br>        <br>PROBLEM:  <br>
# <mark class="entity" style="background: pink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Chronic abdominal pain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASESYNDROME</span>
# </mark>
# ,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nausea
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SIGNSYMPTOM</span>
# </mark>
# , vomiting, abnormal
# <mark class="entity" style="background: pink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     liver
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASESYNDROME</span>
# </mark>
#  function tests.<br> <br><br>HISTORY: <br> The patient is a 23-year-old female referred for evaluation due to a chronic history of
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     abdominal pain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SIGNSYMPTOM</span>
# </mark>
#  and extensive work-up for abnormal
# <mark class="entity" style="background: pink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     liver
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASESYNDROME</span>
# </mark>
#  function tests and this chronic
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nausea
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SIGNSYMPTOM</span>
# </mark>
#  and vomiting referred here for further evaluation due to the patient's recent move from Eugene to Portland.  The patient is not a great historian.  Most of the history is obtained through the old history and chart that the patient has with her.  According to what we can make out, she began experiencing
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nausea
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SIGNSYMPTOM</span>
# </mark>
# , vomiting, recurrent epigastric and right upper quadrant pain in 2001.  She was initially seen by Dr. A back in September 2001 for
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     abdominal pain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SIGNSYMPTOM</span>
# </mark>
# ,
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nausea
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SIGNSYMPTOM</span>
# </mark>
#  and
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vomiting
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SIGNSYMPTOM</span>
# </mark>
# .  During those times, it was suspected that part of her
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     symptoms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SIGNSYMPTOM</span>
# </mark>
#  may be secondary to biliary disease and underwent a cholecystectomy performed in Oregon by Dr.  A in August 2001.  It was assumed that this was caused by biliary dyskinesia.  Previous to that, an upper endoscopy was performed by Dr. B in July 2001 that showed to be mild gastritis secondary to anti-inflammatory use.  Postoperatively she continued to have
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     nausea
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SIGNSYMPTOM</span>
# </mark>
#  and
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vomiting
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SIGNSYMPTOM</span>
# </mark>
# , right upper quadrant
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     abdominal pain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SIGNSYMPTOM</span>
# </mark>
#  and epigastric pain similar to her
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gallbladder
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ANATOMY</span>
# </mark>
#  pain in the past.    In addition, she had significant abnormal
# <mark class="entity" style="background: pink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     liver
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASESYNDROME</span>
# </mark>
#  function tests with ALT in the 600's, AST 300's with a bilirubin 2.5 and alkaline phosphatase in the 200's.  Ultrasound shows
# <mark class="entity" style="background: lightyellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     common bile duct
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ANATOMY</span>
# </mark>
#  of 6 mm post cholecystectomy.  The patient was then eventually referred to Dr. W in Oregon.  Given the abnormal
# <mark class="entity" style="background: pink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     liver
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASESYNDROME</span>
# </mark>
#  function tests and abnormal ultrasound, Dr. W performed an ERCP with sphincterotomy  in September 20, 2001.  Because of the
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     symptoms
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">SIGNSYMPTOM</span>
# </mark>
#  and the suspicions of Sphincter of Oddi dysfunction, a sphincterotomy was performed during the ERCP.  Procedure was uneventful.  The patient did well for a few months, but unfortunately got hospitalized again in May 2002 for recurrence of the
# <mark class="entity" style="background: lightgreen; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     abdominal pain
#     <span style="font-size: 0.8em; font-weight

# %% [markdown]
# What are we actually learning? What are the instances? We can take look at the underlying representation - let's look at the tokens in this document.

# %%
print([(t, t.ent_iob_, t.ent_type_) for t in doc])
# Out:
# [(
#
#
#
#
#
# , 'O', ''), (PROBLEM, 'O', ''), (:, 'O', ''), (
# , 'O', ''), (Chronic, 'B', 'DISEASESYNDROME'), (abdominal, 'I', 'DISEASESYNDROME'), (pain, 'I', 'DISEASESYNDROME'), (,, 'O', ''), (nausea, 'B', 'SIGNSYMPTOM'), (,, 'O', ''), (vomiting, 'O', ''), (,, 'O', ''), (abnormal, 'O', ''), (liver, 'B', 'DISEASESYNDROME'), (function, 'O', ''), (tests, 'O', ''), (., 'O', ''), (
#
#
# , 'O', ''), (HISTORY, 'O', ''), (:, 'O', ''), (
#  , 'O', ''), (The, 'O', ''), (patient, 'O', ''), (is, 'O', ''), (a, 'O', ''), (23, 'O', ''), (-, 'O', ''), (year, 'O', ''), (-, 'O', ''), (old, 'O', ''), (female, 'O', ''), (referred, 'O', ''), (for, 'O', ''), (evaluation, 'O', ''), (due, 'O', ''), (to, 'O', ''), (a, 'O', ''), (chronic, 'O', ''), (history, 'O', ''), (of, 'O', ''), (abdominal, 'B', 'SIGNSYMPTOM'), (pain, 'I', 'SIGNSYMPTOM'), (and, 'O', ''), (extensive, 'O', ''), (work, 'O', ''), (-, 'O', ''), (up, 'O', ''), (for, 'O', ''), (abnormal, 'O', ''), (liver, 'B', 'DISEASESYNDROME'), (function, 'O', ''), (tests, 'O', ''), (and, 'O', ''), (this, 'O', ''), (chronic, 'O', ''), (nausea, 'B', 'SIGNSYMPTOM'), (and, 'O', ''), (vomiting, 'O', ''), (referred, 'O', ''), (here, 'O', ''), (for, 'O', ''), (further, 'O', ''), (evaluation, 'O', ''), (due, 'O', ''), (to, 'O', ''), (the, 'O', ''), (patient, 'O', ''), ('s, 'O', ''), (recent, 'O', ''), (move, 'O', ''), (from, 'O', ''), (Eugene, 'O', ''), (to, 'O', ''), (Portland, 'O', ''), (., 'O', ''), ( , 'O', ''), (The, 'O', ''), (patient, 'O', ''), (is, 'O', ''), (not, 'O', ''), (a, 'O', ''), (great, 'O', ''), (historian, 'O', ''), (., 'O', ''), ( , 'O', ''), (Most, 'O', ''), (of, 'O', ''), (the, 'O', ''), (history, 'O', ''), (is, 'O', ''), (obtained, 'O', ''), (through, 'O', ''), (the, 'O', ''), (old, 'O', ''), (history, 'O', ''), (and, 'O', ''), (chart, 'O', ''), (that, 'O', ''), (the, 'O', ''), (patient, 'O', ''), (has, 'O', ''), (with, 'O', ''), (her, 'O', ''), (., 'O', ''), ( , 'O', ''), (According, 'O', ''), (to, 'O', ''), (what, 'O', ''), (we, 'O', ''), (can, 'O', ''), (make, 'O', ''), (out, 'O', ''), (,, 'O', ''), (she, 'O', ''), (began, 'O', ''), (experiencing, 'O', ''), (nausea, 'B', 'SIGNSYMPTOM'), (,, 'O', ''), (vomiting, 'O', ''), (,, 'O', ''), (recurrent, 'O', ''), (epigastric, 'O', ''), (and, 'O', ''), (right, 'O', ''), (upper, 'O', ''), (quadrant, 'O', ''), (pain, 'O', ''), (in, 'O', ''), (2001, 'O', ''), (., 'O', ''), ( , 'O', ''), (She, 'O', ''), (was, 'O', ''), (initially, 'O', ''), (seen, 'O', ''), (by, 'O', ''), (Dr., 'O', ''), (A, 'O', ''), (back, 'O', ''), (in, 'O', ''), (September, 'O', ''), (2001, 'O', ''), (for, 'O', ''), (abdominal, 'B', 'SIGNSYMPTOM'), (pain, 'I', 'SIGNSYMPTOM'), (,, 'O', ''), (nausea, 'B', 'SIGNSYMPTOM'), (and, 'O', ''), (vomiting, 'B', 'SIGNSYMPTOM'), (., 'O', ''), ( , 'O', ''), (During, 'O', ''), (those, 'O', ''), (times, 'O', ''), (,, 'O', ''), (it, 'O', ''), (was, 'O', ''), (suspected, 'O', ''), (that, 'O', ''), (part, 'O', ''), (of, 'O', ''), (her, 'O', ''), (symptoms, 'B', 'SIGNSYMPTOM'), (may, 'O', ''), (be, 'O', ''), (secondary, 'O', ''), (to, 'O', ''), (biliary, 'O', ''), (disease, 'O', ''), (and, 'O', ''), (underwent, 'O', ''), (a, 'O', ''), (cholecystectomy, 'O', ''), (performed, 'O', ''), (in, 'O', ''), (Oregon, 'O', ''), (by, 'O', ''), (Dr., 'O', ''), ( , 'O', ''), (A, 'O', ''), (in, 'O', ''), (August, 'O', ''), (2001, 'O', ''), (., 'O', ''), ( , 'O', ''), (It, 'O', ''), (was, 'O', ''), (assumed, 'O', ''), (that, 'O', ''), (this, 'O', ''), (was, 'O', ''), (caused, 'O', ''), (by, 'O', ''), (biliary, 'O', ''), (dyskinesia, 'O', ''), (., 'O', ''), ( , 'O', ''), (Previous, 'O', ''), (to, 'O', ''), (that, 'O', ''), (,, 'O', ''), (an, 'O', ''), (upper, 'O', ''), (endoscopy, 'O', ''), (was, 'O', ''), (performed, 'O', ''), (by, 'O', ''), (Dr., 'O', ''), (B, 'O', ''), (in, 'O', ''), (July, 'O', ''), (2001, 'O', ''), (that, 'O', ''), (showed, 'O', ''), (to, 'O', ''), (be, 'O', ''), (mild, 'O', ''), (gastritis, 'O', ''), (secondary, 'O', ''), (to, 'O', ''), (anti, 'O', ''), (-, 'O', ''), (inflammatory, 'O', ''), (use, 'O', ''), (., 'O', ''), ( , 'O', ''), (Postoperatively, 'O', ''), (she, 'O', ''), (continued, 'O', ''), (to, 'O', ''), (have, 'O', ''), (nausea, 'B', 'SIGNSYMPTOM'), (and, 'O', ''), (vomiting, 'B', 'SIGNSYMPTOM'), (,, 'O', ''), (right, 'O', ''), (upper, 'O', ''), (quadrant, 'O', ''), (abdominal, 'B', 'SIGNSYMPTOM'), (pain, 'I', 'SIGNSYMPTOM'), (and, 'O', ''), (epigastric,  ...
#
# , 'O', ''), (During, 'O', ''), (her, 'O', ''), (hospitalization, 'O', ''), (,, 'O', ''), (extensive, 'O', ''), (work, 'O', ''), (-, 'O', ''), (up, 'O', ''), (including, 'O', ''), (CT, 'O', ''), (scan, 'O', ''), (,, 'O', ''), (24, 'O', ''), (hour, 'O', ''), (urine, 'O', ''), (collection, 'O', ''), (for, 'O', ''), (porphyrins, 'O', ''), (,, 'O', ''), (a, 'O', ''), (percutaneous, 'O', ''), (liver, 'O', ''), (biopsy, 'O', ''), (,, 'O', ''), (and, 'O', ''), (Hepatitis, 'O', ''), (panel, 'O', ''), (,, 'O', ''), (all, 'O', ''), (of, 'O', ''), (which, 'O', ''), (were, 'O', ''), (normal, 'O', ''), (., 'O', ''), ( , 'O', ''), (A, 'O', ''), (repeat, 'O', ''), (ERCP, 'O', ''), (with, 'O', ''), (placement, 'O', ''), (of, 'O', ''), (endobiliary, 'O', ''), (stent, 'O', ''), (was, 'O', ''), (uneventful, 'O', ''), (and, 'O', ''), (did, 'O', ''), (not, 'O', ''), (show, 'O', ''), (evidence, 'O', ''), (of, 'O', ''), (PBC, 'O', ''), (or, 'O', ''), (PSC, 'O', ''), (., 'O', ''), ( , 'O', ''), (After, 'O', ''), (placement, 'O', ''), (of, 'O', ''), (the, 'O', ''), (biliary, 'O', ''), (stent, 'O', ''), (,, 'O', ''), (according, 'O', ''), (to, 'O', ''), (Dr., 'O', ''), (W, 'O', ''), ('s, 'O', ''), (note, 'O', ''), (,, 'O', ''), (it, 'O', ''), (apparently, 'O', ''), (helped, 'O', ''), (the, 'O', ''), (patient, 'O', ''), (with, 'O', ''), (her, 'O', ''), (symptoms, 'B', 'SIGNSYMPTOM'), (with, 'O', ''), (decreased, 'O', ''), (frequency, 'O', ''), (of, 'O', ''), (nausea, 'B', 'SIGNSYMPTOM'), (,, 'O', ''), (vomiting, 'O', ''), (,, 'O', ''), (and, 'O', ''), (pain, 'B', 'SIGNSYMPTOM'), (., 'O', ''), ( , 'O', ''), (MRI, 'O', ''), (of, 'O', ''), (the, 'O', ''), (abdomen, 'O', ''), (was, 'O', ''), (also, 'O', ''), (performed, 'O', ''), (in, 'O', ''), (May, 'O', ''), (2002, 'O', ''), (showing, 'O', ''), (a, 'O', ''), (horseshoe, 'O', ''), (kidney, 'O', ''), (,, 'O', ''), (which, 'O', ''), (was, 'O', ''), (previously, 'O', ''), (known, 'O', ''), (on, 'O', ''), (old, 'O', ''), (CT, 'O', ''), (scans, 'O', ''), (., 'O', ''), ( , 'O', ''), (While, 'O', ''), (the, 'O', ''), (biliary, 'O', ''), (stent, 'O', ''), (was, 'O', ''), (in, 'O', ''), (place, 'O', ''), (,, 'O', ''), (the, 'O', ''), (patient, 'O', ''), (did, 'O', ''), (have, 'O', ''), (recurrent, 'O', ''), (bouts, 'O', ''), (of, 'O', ''), (nausea, 'B', 'SIGNSYMPTOM'), (and, 'O', ''), (vomiting, 'B', 'SIGNSYMPTOM'), (and, 'O', ''), (pain, 'O', ''), (rated, 'O', ''), (7, 'O', ''), (out, 'O', ''), (of, 'O', ''), (10, 'O', ''), (in, 'O', ''), (intensity, 'O', ''), (., 'O', ''), (  , 'O', ''), (Finally, 'O', ''), (in, 'O', ''), (August, 'O', ''), (2002, 'O', ''), (,, 'O', ''), (the, 'O', ''), (endobiliary, 'O', ''), (stent, 'O', ''), (was, 'O', ''), (removed, 'O', ''), (and, 'O', ''), (there, 'O', ''), (were, 'O', ''), (no, 'O', ''), (signs, 'O', ''), (of, 'O', ''), (obstruction, 'O', ''), (., 'O', ''), ( , 'O', ''), (Thereafter, 'O', ''), (,, 'O', ''), (the, 'O', ''), (patient, 'O', ''), (actually, 'O', ''), (did, 'O', ''), (fairly, 'O', ''), (well, 'O', ''), (for, 'O', ''), (about, 'O', ''), (a, 'O', ''), (year, 'O', ''), (,, 'O', ''), (but, 'O', ''), (because, 'O', ''), (of, 'O', ''), (a, 'O', ''), (recurrence, 'O', ''), (of, 'O', ''), (her, 'O', ''), (symptoms, 'B', 'SIGNSYMPTOM'), (,, 'O', ''), (Dr., 'O', ''), (W, 'O', ''), (actually, 'O', ''), (sent, 'O', ''), (the, 'O', ''), (patient, 'O', ''), (up, 'O', ''), (to, 'O', ''), (OHSU, 'O', ''), (for, 'O', ''), (evaluation, 'O', ''), (of, 'O', ''), (this, 'O', ''), (continued, 'O', ''), (fairly, 'O', ''), (mysterious, 'O', ''), (abdominal, 'B', 'SIGNSYMPTOM'), (pain, 'I', 'SIGNSYMPTOM'), (., 'O', ''), ( , 'O', ''), (The, 'O', ''), (patient, 'O', ''), (states, 'O', ''), (that, 'O', ''), (she, 'O', ''), (saw, 'O', ''), (Dr., 'O', ''), (A, 'O', ''), (who, 'O', ''), (recommended, 'O', ''), (some, 'O', ''), (laboratory, 'O', ''), (tests, 'O', ''), (and, 'O', ''), (a, 'O', ''), (repeat, 'O', ''), (ERCP, 'O', ''), (for, 'O', ''), (further, 'O', ''), (evaluation, 'O', ''), (, ...
#
# , 'O', ''), (Then, 'O', ''), (,, 'O', ''), (over, 'O', ''), (the, 'O', ''), (course, 'O', ''), (of, 'O', ''), (the, 'O', ''), (next, 'O', ''), (several, 'O', ''), (month, 'O', ''), (,, 'O', ''), (at, 'O', ''), (the, 'O', ''), (beginning, 'O', ''), (of, 'O', ''), (2004, 'O', ''), (,, 'O', ''), (the, 'O', ''), (patient, 'O', ''), ('s, 'O', ''), (symptoms, 'B', 'SIGNSYMPTOM'), (of, 'O', ''), (nausea, 'B', 'SIGNSYMPTOM'), (,, 'O', ''), (vomiting, 'O', ''), (,, 'O', ''), (and, 'O', ''), (recurrence, 'O', ''), (abdominal, 'B', 'SIGNSYMPTOM'), (pain, 'I', 'SIGNSYMPTOM'), (returned, 'O', ''), (., 'O', ''), ( , 'O', ''), (In, 'O', ''), (fact, 'O', ''), (,, 'O', ''), (recently, 'O', ''), (as, 'O', ''), (the, 'O', ''), (last, 'O', ''), (documentation, 'O', ''), (in, 'O', ''), (May, 'O', ''), (and, 'O', ''), (June, 'O', ''), (,, 'O', ''), (the, 'O', ''), (patient, 'O', ''), (visited, 'O', ''), (Emergency, 'O', ''), (Room, 'O', ''), (several, 'O', ''), (times, 'O', ''), (due, 'O', ''), (to, 'O', ''), (her, 'O', ''), (symptoms, 'B', 'SIGNSYMPTOM'), (., 'O', ''), ( , 'O', ''), (Lab, 'O', ''), (tests, 'O', ''), (show, 'O', ''), (normal, 'O', ''), (CBC, 'O', ''), (with, 'O', ''), (no, 'O', ''), (signs, 'O', ''), (of, 'O', ''), (elevated, 'O', ''), (white, 'O', ''), (count, 'O', ''), (., 'O', ''), ( , 'O', ''), (AST, 'O', ''), (and, 'O', ''), (ALT, 'O', ''), (were, 'O', ''), (normal, 'O', ''), (., 'O', ''), ( , 'O', ''), (Alkaline, 'O', ''), (phosphatase, 'O', ''), (was, 'O', ''), (in, 'O', ''), (the, 'O', ''), (low, 'O', ''), (200, 'O', ''), ('s, 'O', ''), (with, 'O', ''), (minimally, 'O', ''), (elevated, 'O', ''), (lipase, 'O', ''), (of, 'O', ''), (78, 'O', ''), (., 'O', ''), ( , 'O', ''), (Bilirubin, 'O', ''), (was, 'O', ''), (completely, 'O', ''), (normal, 'O', ''), (., 'O', ''), ( , 'O', ''), (The, 'O', ''), (patient, 'O', ''), (was, 'O', ''), (given, 'O', ''), (some, 'O', ''), (Zofran, 'O', ''), (and, 'O', ''), (that, 'O', ''), (seemed, 'O', ''), (to, 'O', ''), (control, 'O', ''), (her, 'O', ''), (symptoms, 'B', 'SIGNSYMPTOM'), (and, 'O', ''), (then, 'O', ''), (she, 'O', ''), (was, 'O', ''), (discharged, 'O', ''), (and, 'O', ''), (now, 'O', ''), (referred, 'O', ''), (to, 'O', ''), (us, 'O', ''), (for, 'O', ''), (further, 'O', ''), (evaluation, 'O', ''), (., 'O', ''), ( , 'O', ''), (At, 'O', ''), (the, 'O', ''), (present, 'O', ''), (time, 'O', ''), (,, 'O', ''), (the, 'O', ''), (patient, 'O', ''), (is, 'O', ''), (not, 'O', ''), (having, 'O', ''), (any, 'O', ''), (abdominal, 'B', 'SIGNSYMPTOM'), (pain, 'I', 'SIGNSYMPTOM'), (., 'O', ''), ( , 'O', ''), (She, 'O', ''), (states, 'O', ''), (she, 'O', ''), (threw, 'O', ''), (up, 'O', ''), (three, 'O', ''), (times, 'O', ''), (in, 'O', ''), (the, 'O', ''), (morning, 'O', ''), (and, 'O', ''), (is, 'O', ''), (feeling, 'O', ''), (well, 'O', ''), (at, 'O', ''), (this, 'O', ''), (point, 'O', ''), (., 'O', ''), ( , 'O', ''), (Her, 'O', ''), (abdominal, 'B', 'SIGNSYMPTOM'), (pain, 'I', 'SIGNSYMPTOM'), (,, 'O', ''), (nausea, 'B', 'SIGNSYMPTOM'), (and, 'O', ''), (vomiting, 'O', ''), (symptoms, 'O', ''), (are, 'O', ''), (random, 'O', ''), (., 'O', ''), ( , 'O', ''), (It, 'O', ''), (does, 'O', ''), (not, 'O', ''), (associate, 'O', ''), (with, 'O', ''), (food, 'O', ''), (., 'O', ''), ( , 'O', ''), (It, 'O', ''), (is, 'O', ''), (not, 'O', ''), (pre, 'O', ''), (or, 'O', ''), (post, 'O', ''), (meal, 'O', ''), (and, 'O', ''), (occasionally, 'O', ''), (will, 'O', ''), (wake, 'O', ''), (her, 'O', ''), (up, 'O', ''), (in, 'O', ''), (the, 'O', ''), (middle, 'O', ''), (of, 'O', ''), (the, 'O', ''), (night, 'O', ''), (., 'O', ''), ( , 'O', ''), (She, 'O', ''), (has, 'O', ''), (not, 'O', ''), (lost, 'O', ''), (any, 'O', ''), (weight, 'O', ''), (despite, 'O', ''), (this, 'O', ''), (chronic, 'O', ''), (nausea, 'B', 'SIGNSYMPTOM'), (and, 'O', ''), (vomiting, 'B', 'SIGNSYMPTOM'), (and, 'O', ''), (abdominal, 'B', 'SIGNSYMPTOM'), (pain, 'I', 'SIGNSYMPTOM'), (., 'O', ''), ( , 'O', ''), (Her, 'O', ''), (bowel, 'O', ''), (habits, ...
#
#
# , 'O', ''), (ALLERGIES, 'O', ''), (:, 'O', ''), (
#  , 'O', ''), (The, 'O', ''), (patient, 'O', ''), (has, 'O', ''), (allergies, 'O', ''), (to, 'O', ''), (Sulfa, 'O', ''), (and, 'O', ''), (Codeine, 'O', ''), (., 'O', ''), (
#
#
# , 'O', ''), (OPERATIONS, 'O', ''), (:, 'O', ''), (
#  , 'O', ''), (Laparoscopic, 'O', ''), (cholecystectomy, 'O', ''), (,, 'O', ''), (two, 'O', ''), (ERCP, 'O', ''), ('s, 'O', ''), (including, 'O', ''), (stent, 'O', ''), (placement, 'O', ''), (and, 'O', ''), (sphincterotomy, 'O', ''), (., 'O', ''), (
#
#
# , 'O', ''), (ILLNESSES, 'O', ''), (:, 'O', ''), (
#  , 'O', ''), (Juvenile, 'O', ''), (rheumatoid, 'O', ''), (arthritis, 'O', ''), (for, 'O', ''), (which, 'O', ''), (Dr., 'O', ''), (B, 'O', ''), (is, 'O', ''), (following, 'O', ''), (., 'O', ''), (
#
#
# , 'O', ''), (MEDICATIONS, 'O', ''), (:, 'O', ''), (
# , 'O', ''), (The, 'O', ''), (patient, 'O', ''), (is, 'O', ''), (on, 'O', ''), (some, 'O', ''), (type, 'O', ''), (of, 'O', ''), (anti, 'O', ''), (-, 'O', ''), (inflammatory, 'O', ''), (,, 'O', ''), (for, 'O', ''), (which, 'O', ''), (the, 'O', ''), (name, 'B', 'ANATOMY'), (is, 'O', ''), (unknown, 'O', ''), (to, 'O', ''), (her, 'O', ''), (., 'O', ''), ( , 'O', ''), (She, 'O', ''), (is, 'O', ''), (also, 'O', ''), (taking, 'O', ''), (some, 'O', ''), (Zofran, 'O', ''), (., 'O', ''), (
#
#
# , 'O', ''), (HABITS, 'O', ''), (:, 'O', ''), (
#  , 'O', ''), (She, 'O', ''), (does, 'O', ''), (not, 'O', ''), (drink, 'O', ''), (or, 'O', ''), (smoke, 'O', ''), (., 'O', ''), (
#
#
# , 'O', ''), (SOCIAL, 'O', ''), (HISTORY, 'O', ''), (:, 'O', ''), (
#  , 'O', ''), (The, 'O', ''), (patent, 'O', ''), (moved, 'O', ''), (up, 'O', ''), (from, 'O', ''), (Eugene, 'O', ''), (., 'O', ''), ( , 'O', ''), (She, 'O', ''), (currently, 'O', ''), (lives, 'O', ''), (up, 'O', ''), (here, 'O', ''), (and, 'O', ''), (works, 'O', ''), (in, 'O', ''), (Portland, 'O', ''), (., 'O', ''), (
#
#
# , 'O', ''), (FAMILY, 'O', ''), (HISTORY, 'O', ''), (:, 'O', ''), (
#   , 'O', ''), (Noncontributory, 'O', ''), (., 'O', ''), (
#
#
# , 'O', ''), (REVIEW, 'O', ''), (OF, 'O', ''), (SYSTEMS, 'O', ''), (:, 'O', ''), (
#  , 'O', ''), (The, 'O', ''), (patient, 'O', ''), (has, 'O', ''), (seen, 'O', ''), (primarily, 'O', ''), (Dr., 'O', ''), (B, 'O', ''), (,, 'O', ''), (her, 'O', ''), (rheumatologist, 'O', ''), (,, 'O', ''), (as, 'O', ''), (primary, 'O', ''), (care, 'O', ''), (., 'O', ''), (
#
#
# , 'O', ''), (DATA, 'O', ''), (:, 'O', ''), (
#  , 'O', ''), (The, 'O', ''), (patient, 'O', ''), ('s, 'O', ''), (extensive, 'O', ''), (chart, 'O', ''), (was, 'O', ''), (reviewed, 'O', ''), (., 'O', ''), ( , 'O', ''), (It, 'O', ''), (took, 'O', ''), (over, 'O', ''), (45, 'O', ''), (minutes, 'O', ''), (to, 'O', ''), (sort, 'O', ''), (through, 'O', ''), (the, 'O', ''), (chart, 'O', ''), (and, 'O', ''), (the, 'O', ''), (labs, 'O', ''), (., 'O', ''), (
#
#
# , 'O', ''), (PHYSICAL, 'O', ''), (EXAMINATION, 'O', ''), (:, 'O', ''), (
#  , 'O', ''), (The, 'O', ''), (patient, 'O', ''), (is, 'O', ''), (a, 'O', ''), ( , 'O', ''), (23, 'O', ''), (-, 'O', ''), (year, 'O', ''), (old, 'O', ''), (female, 'O', ''), (who, 'O', ''), (appears, 'O', ''), (well, 'O', ''), (developed, 'O', ''), (with, 'O', ''), (no, 'O', ''), (acute, 'O', ''), (signs, 'O', ''), (of, 'O', ''), (distress, 'O', ''), (., 'O', ''), ( , 'O', ''), (HENT, 'O', ''), (:, 'O', ''), ( , 'O', ''), (Normocephalic, 'O', ''), (,, 'O', ''), (atraumatic, 'O', ''), (,, 'O', ''), (PERRLA, 'O', ''), (,, 'O', ''), (EOMI, 'O', ''), (,, 'O', ''), (sclerae, 'O', ''), (are, 'O', ''), (anicteric, 'O', ''), (., 'O', ''), ( , 'O', ''), (Nares, 'O', ''), (are, 'O', ''), (patent, 'O', ''), (and, 'O', ''), (symmetrical, 'O', ''), (., 'O', ''), ( , 'O', ''), (The, 'O', ''), (oropharynx, 'O', ''), (is, 'O', ''), (clear, 'O', ''), (with, 'O', ''), (moist, 'O', ''), (mucus, 'O', ''), (membranes, 'O', ''), (and, 'O', ''), (no, 'O', ''), (obvious, 'O', ''), (mucosal, 'O', ''), (lesions, 'O', ''), (., 'O', ''), ( , 'O', ''), (The, 'O', ''), (tongue, 'O', ''), (is, 'O', ''), (midline, 'O', ''), (., 'O', ''), ( , 'O', ''), (NECK, 'O', ''), (:, 'O', ''), ( , 'O', ''), (Supple, 'O', ''), (without, 'O', ''), (adenopathy, 'O', ''), (,, 'O', ''), (JVD, 'O', ''), (,, 'O', ''), (or, 'O', ''), (thyromegaly, 'O', ''), (., 'O', ''), ( , 'O', ''), (There, 'O', ''), ('s, 'O', ''), (no, 'O', ''), (supraclavicular, 'O', ''), (adenopathy, 'O', ''), (., 'O', ''), ( , 'O', ''), (LUNGS, 'O', ''), (:, 'O', ''), ( , 'O', ''), (Clear, 'O', ''), (bilaterally, 'O', ''), (with, 'O', ''), (normal, 'O', ''), (respiratory, 'O', ''), (effort, 'O', ''), (., 'O', ''), ( , 'O', ''), (BACK, 'O', ''), (:, 'O', ''), ( , 'O', ''), (Nontender, 'O', ''), (to, 'O', ''), (palpation, 'O', ''), (and, 'O', ''), (there, 'O', ''), ('s, 'O', ''), (no, 'O', ''), (CVA, 'O', ''), (tenderness, 'B', 'ANATOMY'), (or, 'O', ''), (obvious, 'O', ''), (spinal, 'O', ''), (deformity, 'O', ''), (., 'O', ''), ( , 'O', ''), (CARDIAC, 'O', ''), (:, 'O', ''), ( , 'O', ''), (Regular, 'O', ''), (rate, 'O', ''), (and, 'O', ''), (rhythm, 'O', ''), (., 'O', ''), (No, 'O', ''), (murmur, 'O', ''), (., 'O', ''), ( , 'O', ''), (ABDOMEN, 'O', ''), (:, 'O', ''), ( , 'O', ''), (Soft, 'O', ''), (,, 'O', ''), (nondistended, 'O', ''), (and, 'O', ''), (nontender, 'O', ''), (to, 'O', ''), (palpation, 'O', ''), (throughout, 'O', ''), (with, 'O', ''), (no, 'O', ''), (appreciable, 'O', ''), (hepatosplenomegaly, 'O', ''), (,, 'O', ''), (masses, 'O', ''), (,, 'O', ''), (fullness, 'O', ''), (or, 'O', ''), (ascites, 'O', ''), (., 'O', ''), ( , 'O', ''), (Bowel, 'O', ''), (sounds, 'O', ''), (were, 'O', ''), (present, 'O', ''), (and, 'O', ''), (did, 'O', ''), (appear, 'O', ''), (normal, 'O', ''), (., 'O', ''), ( , 'O', ''), (RECTAL, 'O', ''), (:, 'O', ''), ( , 'O', ''), (Deferred, 'O', ''), (., 'O', ''), ( , 'O', ''), (EXTREMITIES, 'O', ''), (:, 'O', ''), ( , 'O', ''), (Without, 'O', ''), (edema, 'O', ''), (,, 'O', ''), (calf, 'O', ''), (tenderness, 'O', ''), (or, 'O', ''), (joint, 'O', ''), (swelling, 'O', ''), (., 'O', ''), ( , 'O', ''), (NEUROLOGIC, 'O', ''), (:, 'O', ''), ( , 'O', ''), (Shows, 'O', ''), (the, 'O', ''), (patient, 'O', ''), (to, 'O', ''), (be, 'O', ''), (alert, 'O', ''), (and, 'O', ''), (oriented, 'O', ''), (x, 'O', ''), ('s, 'O', ''), (3, 'O', ''), (with, 'O', ''), (normal, 'O', ''), (gait, 'O', ''), (., 'O', ''), ( , 'O', ''), (SKIN, 'O', ''), (:, 'O', ''), ( , 'O', ''), (Warm, 'O', ''), (and, 'O', ''), (dry, 'O', ''), (with, 'O', ''), (normal, 'O', ''), (color, 'O', ''), (and, 'O', ''), (no, 'O', ''), (rashes, 'O', ''), (., 'O', ''), (
#
#
# , 'O', ''), (IMPRESSION, 'O', ''), (:, 'O', ''), (
#  , 'O', ''), (A, 'O', ''), (23, 'O', ''), (-, 'O', ''), (year, 'O', ''), (-, 'O', ''), (old, 'O', ''), (female, 'O', ''), (with, 'O', ''), (fairly, 'O', ''), (mysterious, 'O', ''), (symptoms, 'O', ''), (of, 'O', ''), (nausea, 'B', 'SIGNSYMPTOM'), (,, 'O', ''), (vomiting, 'O', ''), (,, 'O', ''), (and, 'O', ''), (abdominal, 'B', 'SIGNSYMPTOM'), (pain, 'I', 'SIGNSYMPTOM'), (status, 'O', ''), (post, 'O', ''), (cholecystectomy, 'O', ''), (and, 'O', ''), (ERCP, 'O', ''), (with, 'O', ''), (sphincterotomy, 'O', ''), (., 'O', ''), ( , 'O', ''), (She, 'O', ''), (continues, 'O', ''), (to, 'O', ''), (have, 'O', ''), (very, 'O', ''), (intermittent, 'O', ''), (elevated, 'O', ''), (liver, 'B', 'DISEASESYNDROME'), (function, 'O', ''), (tests, 'O', ''), (and, 'O', ''), (symptoms, 'B', 'SIGNSYMPTOM'), (of, 'O', ''), (nausea, 'B', 'SIGNSYMPTOM'), (,, 'O', ''), (vomiting, 'O', ''), (,, 'O', ''), (and, 'O', ''), (abdominal, 'B', 'SIGNSYMPTOM'), (pain, 'I', 'SIGNSYMPTOM'), (., 'O', ''), ( , 'O', ''), (There, 'O', ''), (was, 'O', ''), (some, 'O', ''), (discussion, 'O', ''), (with, 'O', ''), (Dr., 'O', ''), (W, 'O', ''), (in, 'O', ''), (the, 'O', ''), (past, 'O', ''), (regarding, 'O', ''), (extending, 'O', ''), (the, 'O', ''), (sphincterotomy, 'O', ''), (to, 'O', ''), (ensure, 'O', ''), (that, 'O', ''), (a, 'O', ''), (complete, 'O', ''), (sphincterotomy, 'O', ''), (was, 'O', ''), (performed, 'O', ''), (if, 'O', ''), (the, 'O', ''), (patient, 'O', ''), (should, 'O', ''), (have, 'O', ''), (sphincter, 'O', ''), (of, 'O', ''), (Oddi, 'O', ''), (dysfunction, 'O', ''), (,, 'O', ''), (however, 'O', ''), (,, 'O', ''), (at, 'O', ''), (this, 'O', ''), (time, 'O', ''), (I, 'O', ''), (am, 'O', ''), (reluctant, 'O', ''), (to, 'O', ''), (do, 'O', ''), (so, 'O', ''), (without, 'O', ''), (further, 'O', ''), (reviewing, 'O', ''), (the, 'O', ''), (patient, 'O', ''), ('s, 'O', ''), (chart, 'O', ''), (and, 'O', ''), (investigating, 'O', ''), (other, 'O', ''), (avenues, 'O', ''), (., 'O', ''), ( , 'O', ''), (I, 'O', ''), (think, 'O', ''), (we, 'O', ''), (will, 'O', ''), (check, 'O', ''), (another, 'O', ''), (repeat, 'O', ''), (liver, 'B', 'DISEASESYNDROME'), (function, 'O', ''), (test, 'O', ''), (and, 'O', ''), (I, 'O', ''), (think, 'O', ''), (it, 'O', ''), (may, 'O', ''), (be, 'O', ''), (helpful, 'O', ''), (to, 'O', ''), (repeat, 'O', ''), (a, 'O', ''), (liver, 'B', 'DISEASESYNDROME'), (biopsy, 'O', ''), (to, 'O', ''), (ensure, 'O', ''), (we, 'O', ''), (are, 'O', ''), (not, 'O', ''), (missing, 'O', ''), (other, 'O', ''), (primary, 'O', ''), (liver, 'B', 'DISEASESYNDROME'), (diseases, 'O', ''), (before, 'O', ''), (concentrating, 'O', ''), (purely, 'O', ''), (on, 'O', ''), (the, 'O', ''), (biliary, 'O', ''), (tree, 'O', ''), (itself, 'O', ''), (., 'O', ''), ( , 'O', ''), (In, 'O', ''), (addition, 'O', ''), (,, 'O', ''), (AMA, 'O', ''), (will, 'O', ''), (be, 'O', ''), (obtained, 'O', ''), (along, 'O', ''), (with, 'O', ''), (a, 'O', ''), (liver, 'B', 'DISEASESYNDROME'), (function, 'O', ''), (test, 'O', ''), (., 'O', ''), ( , 'O', ''), (I, 'O', ''), (would, 'O', ''), (also, 'O', ''), (like, 'O', ''), (to, 'O', ''), (obtain, 'O', ''), (some, 'O', ''), (discharge, 'O', ''), (summaries, 'O', ''), (from, 'O', ''), (Dr., 'O', ''), (W, 'O', ''), ('s, 'O', ''), (office, 'O', ''), (to, 'O', ''), (further, 'O', ''), (clarify, 'O', ''), (what, 'O', ''), (has, 'O', ''), (transpired, 'O', ''), (over, 'O', ''), (the, 'O', ''), (past, 'O', ''), (three, 'O', ''), (years, 'O', ''), (., 'O', ''), (
#
#
# , 'O', ''), (PLAN, 'O', ''), (:, 'O', ''), (
#
# , 'O', ''), (1, 'O', ''), (., 'O', ''), ( , 'O', ''), (Obtain, 'O', ''), (discharge, 'O', ''), (summaries, 'O', ''), (from, 'O', ''), (Dr., 'O', ''), (W, 'O', ''), ('s, 'O', ''), (office, 'O', ''), (., 'O', ''), (
# , 'O', ''), (2, 'O', ''), (., 'O', ''), ( , 'O', ''), (Send, 'O', ''), (the, 'O', ''), (patient, 'O', ''), (for, 'O', ''), (a, 'O', ''), (complete, 'O', ''), (metabolic, 'O', ''), (panel, 'O', ''), (,, 'O', ''), (AMA, 'O', ''), (., 'O', ''), (
# , 'O', ''), (3, 'O', ''), (., 'O', ''), ( , 'O', ''), (Send, 'O', ''), (the, 'O', ''), (patient, 'O', ''), (for, 'O', ''), (ultrasound, 'O', ''), (and, 'O', ''), (possible, 'O', ''), (ultrasound, 'O', ''), (guided, 'O', ''), (liver, 'B', 'DISEASESYNDROME'), (biopsy, 'O', ''), (., 'O', ''), (
# , 'O', ''), (4, 'O', ''), (., 'O', ''), ( , 'O', ''), (The, 'O', ''), (patient, 'O', ''), (will, 'O', ''), (return, 'O', ''), (to, 'O', ''), (see, 'O', ''), (me, 'O', ''), (in, 'O', ''), (three, 'O', ''), (weeks, 'O', ''), (., 'O', ''), ( , 'O', ''), (We, 'O', ''), (will, 'O', ''), (consider, 'O', ''), (further, 'O', ''), (options, 'O', ''), (pending, 'O', ''), (on, 'O', ''), (these, 'O', ''), (results, 'O', ''), (of, 'O', ''), (the, 'O', ''), (test, 'O', ''), (and, 'O', ''), (review, 'O', ''), (of, 'O', ''), (the, 'O', ''), (patient, 'O', ''), ('s, 'O', ''), (discharge, 'O', ''), (summaries, 'O', ''), (from, 'O', ''), (Dr., 'O', ''), (W, 'O', ''), ('s, 'O', ''), (office, 'O', ''), (., 'O', ''), ( , 'O', ''), (If, 'O', ''), (the, 'O', ''), (patient, 'O', ''), (should, 'O', ''), (show, 'O', ''), (symptoms, 'B', 'SIGNSYMPTOM'), (of, 'O', ''), (pain, 'B', 'SIGNSYMPTOM'), (and, 'O', ''), (elevated, 'O', ''), (liver, 'B', 'DISEASESYNDROME'), (function, 'O', ''), (tests, 'O', ''), (to, 'O', ''), (be, 'O', ''), (consistent, 'O', ''), (with, 'O', ''), (Sphincter, 'O', ''), (of, 'O', ''), (Oddi, 'O', ''), (dysfunction, 'O', ''), (,, 'O', ''), (we, 'O', ''), (may, 'O', ''), (repeat, 'O', ''), (the, 'O', ''), (ERCP, 'O', ''), (and, 'O', ''), (extend, 'O', ''), (the, 'O', ''), (sphincterotomy, 'O', ''), (., 'O', ''), ( , 'O', ''), (The, 'O', ''), (entire, 'O', ''), (case, 'O', ''), (was, 'O', ''), (discussed, 'O', ''), (with, 'O', ''), (the, 'O', ''), (patient, 'O', ''), (., 'O', ''), ( , 'O', ''), (The, 'O', ''), (patient, 'O', ''), (is, 'O', ''), (agreeable, 'O', ''), (to, 'O', ''), (the, 'O', ''), (current, 'O', ''), (plan, 'O', ''), (., 'O', ''), ( , 'O', ''), (Thank, 'O', ''), (you, 'O', ''), (for, 'O', ''), (this, 'O', ''), (consultation, 'O', ''), (., 'O', ''), (
#
#
# , 'O', ''), (FOLLOWUP, 'O', ''), (:, 'O', ''), (
# , 'O', ''), (In, 'O', ''), (two, 'O', ''), (to, 'O', ''), (three, 'O', ''), (weeks, 'O', ''), (., 'O', ''), (
#
#
#
#
# , 'O', '')]

# %% [markdown]
# What do you think? Does it seem like the model works well on this document? Are there concepts that are missed?

# %% [markdown]
# # 6: Evaluation
# How do we know how good this model is? Let's compare with the held out test data. First you will need to load this in, just like we loaded in the training data. Complete the code below to do this.

# %%
import requests

data_url = 'https://github.com/KCL-Health-NLP/nlp_examples/blob/master/chunking/chunking_testdata_CAT_updated_2021.json?raw=true'

r = requests.get(data_url)
test_data = r.json()

# %% [markdown]
# Spacy's *Scorer* takes a list of *Examples*. An Example contains two Documents, one with the fold standard annotations, and one with the predicted annotations.

# %%
# We create a list to hold our Examples
examples = []

# The scorer
scorer = Scorer()

# Iterate over the text and annotations in our test data
for text, annotations in test_data:

    # Run the ner over the text to make predictions
    doc = ner(text)

    # Create the Example from the predicted doc
    # and the gold annotations, add it to our list
    example = Example.from_dict(doc, annotations)
    examples.append(example)

# Score the examples
scores = scorer.score(examples)

print('Precision: ', scores['ents_p'])
print('Recall: ', scores['ents_r'])
print('F1: ', scores['ents_f'])
# Out:
# /usr/local/lib/python3.12/dist-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "
#
#
#
#
#
# ADMITTI..." with entities "[[320, 325, 'ANATOMY'], [1073, 1080, 'ANATOMY'], [...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Precision:  0.8362831858407079
# Recall:  0.3271783035199077
# F1:  0.4703442554956449

# %% [markdown]
# Are these good results do you think? Can this be improved? What happens if you increase the number of iterations in the training?

# %% [markdown]
# The scores dictionary also contains a dictionary of scores per entity type. You can access this from scores['ents_per_type']. Write code to print out these scores in an easy to red format.

# %%
  # Write code to print out scores['ents_per_type'] in an easy to read format
  # e.g. you might iterate over the labels and the metrics in two nested loops
for label, metrics in scores['ents_per_type'].items():
    print(f"\nLabel: {label}")
    print(f"  Precision: {metrics['p']:.3f}")
    print(f"  Recall:    {metrics['r']:.3f}")
    print(f"  F1-score:  {metrics['f']:.3f}")
# Out:
# Label: SIGNSYMPTOM
#   Precision: 0.706
#   Recall:    0.234
#   F1-score:  0.351
#
# Label: DISEASESYNDROME
#   Precision: 0.761
#   Recall:    0.212
#   F1-score:  0.332
#
# Label: ANATOMY
#   Precision: 0.889
#   Recall:    0.416
#   F1-score:  0.567

# %% [markdown]
# Let's look at a document from the test data, using displacy. You can do this using the same steps we did before. Write the code below.

# %%
# Complete the code to process an example document, and
# then display it.
text = test_data[37][0]

# %% [markdown]
# What does the underlying representation look like?

# %%
print([(t, t.ent_iob_, t.ent_type_) for t in doc])
# Out:
# [(
#
#
#
#
#
# , 'O', ''), (EXAM, 'O', ''), (:, 'O', ''), (
#  , 'O', ''), (Ultrasound, 'O', ''), (abdomen, 'O', ''), (,, 'O', ''), (complete, 'O', ''), (., 'O', ''), (
#
#
# , 'O', ''), (HISTORY, 'O', ''), (:, 'O', ''), (
#  , 'O', ''), (38, 'O', ''), (-, 'O', ''), (year, 'O', ''), (-, 'O', ''), (old, 'O', ''), (male, 'O', ''), (admitted, 'O', ''), (from, 'O', ''), (the, 'O', ''), (emergency, 'O', ''), (room, 'O', ''), (04/18/2009, 'O', ''), (,, 'O', ''), (decreased, 'O', ''), (mental, 'O', ''), (status, 'O', ''), (and, 'O', ''), (right, 'O', ''), (upper, 'O', ''), (lobe, 'O', ''), (pneumonia, 'O', ''), (., 'O', ''), ( , 'O', ''), (The, 'O', ''), (patient, 'O', ''), (has, 'O', ''), (diffuse, 'O', ''), (abdominal, 'B', 'SIGNSYMPTOM'), (pain, 'I', 'SIGNSYMPTOM'), (., 'O', ''), ( , 'O', ''), (There, 'O', ''), (is, 'O', ''), (a, 'O', ''), (history, 'O', ''), (of, 'O', ''), (AIDS, 'O', ''), (., 'O', ''), (
#
#
# , 'O', ''), (TECHNIQUE, 'O', ''), (:, 'O', ''), (
#   , 'O', ''), (An, 'O', ''), (ultrasound, 'O', ''), (examination, 'O', ''), (of, 'O', ''), (the, 'O', ''), (abdomen, 'O', ''), (was, 'O', ''), (performed, 'O', ''), (., 'O', ''), (
#
#
# , 'O', ''), (FINDINGS, 'O', ''), (:, 'O', ''), (
#   , 'O', ''), (The, 'O', ''), (liver, 'O', ''), (has, 'O', ''), (normal, 'O', ''), (echogenicity, 'O', ''), (., 'O', ''), ( , 'O', ''), (The, 'O', ''), (liver, 'B', 'DISEASESYNDROME'), (is, 'O', ''), (normal, 'O', ''), (sized, 'O', ''), (., 'O', ''), ( , 'O', ''), (The, 'O', ''), (gallbladder, 'B', 'ANATOMY'), (has, 'O', ''), (a, 'O', ''), (normal, 'O', ''), (appearance, 'O', ''), (without, 'O', ''), (gallstones, 'O', ''), (or, 'O', ''), (sludge, 'O', ''), (., 'O', ''), ( , 'O', ''), (There, 'O', ''), (is, 'O', ''), (no, 'O', ''), (gallbladder, 'B', 'ANATOMY'), (wall, 'O', ''), (thickening, 'O', ''), (or, 'O', ''), (pericholecystic, 'O', ''), (fluid, 'O', ''), (., 'O', ''), ( , 'O', ''), (The, 'O', ''), (common, 'B', 'ANATOMY'), (bile, 'I', 'ANATOMY'), (duct, 'I', 'ANATOMY'), (has, 'O', ''), (a, 'O', ''), (normal, 'O', ''), (caliber, 'O', ''), (at, 'O', ''), (4.6, 'O', ''), (mm, 'O', ''), (., 'O', ''), ( , 'O', ''), (The, 'O', ''), (pancreas, 'O', ''), (is, 'O', ''), (mostly, 'O', ''), (obscured, 'O', ''), (by, 'O', ''), (gas, 'O', ''), (., 'O', ''), ( , 'O', ''), (A, 'O', ''), (small, 'O', ''), (portion, 'O', ''), (of, 'O', ''), (the, 'O', ''), (head, 'O', ''), (of, 'O', ''), (pancreas, 'O', ''), (is, 'O', ''), (visualized, 'O', ''), (which, 'O', ''), (has, 'O', ''), (a, 'O', ''), (normal, 'O', ''), (appearance, 'O', ''), (., 'O', ''), ( , 'O', ''), (The, 'O', ''), (aorta, 'O', ''), (has, 'O', ''), (a, 'O', ''), (normal, 'O', ''), (caliber, 'O', ''), (., 'O', ''), ( , 'O', ''), (The, 'O', ''), (aorta, 'O', ''), (is, 'O', ''), (smooth, 'O', ''), (walled, 'O', ''), (., 'O', ''), ( , 'O', ''), (No, 'O', ''), (abnormalities, 'O', ''), (are, 'O', ''), (seen, 'O', ''), (of, 'O', ''), (the, 'O', ''), (inferior, 'O', ''), (vena, 'O', ''), (cava, 'O', ''), (., 'O', ''), ( , 'O', ''), (The, 'O', ''), (right, 'B', 'ANATOMY'), (kidney, 'I', 'ANATOMY'), (measures, 'O', ''), (10.8, 'O', ''), (cm, 'O', ''), (in, 'O', ''), (length, 'O', ''), (and, 'O', ''), (the, 'O', ''), (left, 'O', ''), (kidney, 'O', ''), (10.5, 'O', ''), (cm, 'O', ''), (., 'O', ''), ( , 'O', ''), (No, 'O', ''), (masses, 'O', ''), (,, 'O', ''), (cysts, 'O', ''), (,, 'O', ''), (calculi, 'O', ''), (,, 'O', ''), (or, 'O', ''), (hydronephrosis, 'O', ''), (is, 'O', ''), (seen, 'O', ''), (., 'O', ''), ( , 'O', ''), (There, 'O', ''), (is, 'O', ''), (normal, 'O', ''), (renal, 'O', ''), (cortical, 'O', ''), (echogenicity, 'O', ''), (., 'O', ''), ( , 'O', ''), (The, 'O', ''), (spleen, 'O', ''), (is, 'O', ''), (somewhat, 'O', ''), (prominent, 'O', ''), (with, 'O', ''), (a, 'O', ''), (maximum, 'O', ''), (diameter, 'O', ''), (of, 'O', ''), (11.2, 'O', ''), (cm, 'O', ''), (., 'O', ''), ( , 'O', ''), (There, 'O', ''), (is, 'O', ''), (no, 'O', ''), (ascites, 'O', ''), (., 'O', ''), ( , 'O', ''), (The, 'O', ''), (urinary, 'O', ''), (bladder, 'O', ''), (is, 'O', ''), (distended, 'O', ''), (with, 'O', ''), (urine, 'O', ''), (and, 'O', ''), (shows, 'O', ''), (normal, 'O', ''), (wall, 'O', ''), (thickness, 'O', ''), (without, 'O', ''), (masses, 'O', ''), (., 'O', ''), ( , 'O', ''), (The, 'O', ''), (prostate, 'O', ''), (is, 'O', ''), (normal, 'O', ''), (sized, 'O', ''), (with, 'O', ''), (normal, 'O', ''), (echogenicity, 'O', ''), (., 'O', ''), (
#
#
# , 'O', ''), (IMPRESSION, 'O', ''), (:, 'O', ''), (
#
# , 'O', ''), (1, 'O', ''), (., 'O', ''), ( , 'O', ''), (Spleen, 'O', ''), (size, 'O', ''), (at, 'O', ''), (the, 'O', ''), (upper, 'O', ''), (limits, 'O', ''), (of, 'O', ''), (normal, 'O', ''), (., 'O', ''), (
# , 'O', ''), (2, 'O', ''), (., 'O', ''), ( , 'O', ''), (Except, 'O', ''), (for, 'O', ''), (small, 'O', ''), (portions, 'O', ''), (of, 'O', ''), (pancreatic, 'O', ''), (head, 'O', ''), (,, 'O', ''), (the, 'O', ''), (pancreas, 'O', ''), (could, 'O', ''), (not, 'O', ''), (be, 'O', ''), (visualized, 'O', ''), (because, 'O', ''), (of, 'O', ''), (bowel, 'O', ''), (gas, 'O', ''), (., 'O', ''), ( , 'O', ''), (The, 'O', ''), (visualized, 'O', ''), (portion, 'O', ''), (of, 'O', ''), (the, 'O', ''), (head, 'O', ''), (had, 'O', ''), (a, 'O', ''), (normal, 'O', ''), (appearance, 'O', ''), (., 'O', ''), (
# , 'O', ''), (3, 'O', ''), (., 'O', ''), ( , 'O', ''), (The, 'O', ''), (gallbladder, 'B', 'ANATOMY'), (has, 'O', ''), (a, 'O', ''), (normal, 'O', ''), (appearance, 'O', ''), (without, 'O', ''), (gallstones, 'O', ''), (., 'O', ''), ( , 'O', ''), (There, 'O', ''), (are, 'O', ''), (no, 'O', ''), (renal, 'O', ''), (calculi, 'O', ''), (., 'O', ''), (
#
#
#
#
# , 'O', '')]

# %% [markdown]
# There are other options available using spaCy, training models etc. If interested, look at their website, e.g. https://spacy.io/usage/training
